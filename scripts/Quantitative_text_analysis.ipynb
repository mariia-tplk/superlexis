# %%
### pipeline for topic models to time series 

# create a doc-topic matrix
path = ' # Change this to the preferred or relevant location on your computer
os.chdir(path)

import numpy as np

filenames = df1['index'].values.astype('U')

dates = df1['year'].values.astype('U') # its better to use the date string here

dtm_transformed = tf_vectorizer.fit_transform(df1['Review_Text'].values.astype('U'))

doctopic = lda_tf.fit_transform(dtm_transformed)

doctopic = doctopic / np.sum(doctopic, axis=1, keepdims=True)

# Write doctopic to a csv file
# I need to thank Damian Trilling for helping me with the code to turn the "doctopic" into a readable .CSV
os.chdir(path)  

i=0
with open('disney.csv',mode='w') as fo:
    for rij in doctopic:
        fo.write('"'+filenames[i]+'"')
        fo.write(',')
        fo.write('"'+dates[i]+'"')
        fo.write(',')
        for kolom in rij:
            fo.write(str(kolom))
            fo.write(',')
        fo.write('\n')
        i+=1
print("finsihed with creating doctopic matrix")

dfm = pd.read_csv('C:/Users/User/Desktop/disney.csv', header=None, index_col=False,
                  names = ["file", "year", "t_0", "t_1","t_2", "t_3", "t_4", "t_5", "t_6", "t_7", "t_8", "t_9"])

# calculate mean, std, cutoff high, and cutoff low
dfm1 = dfm.describe().loc[['mean','std']]
dfm2 = dfm1.transpose()
dfm2['cutoff_low'] = dfm2['mean'] + dfm2['std']

# Drop first two rows
dfm2 = dfm2.iloc[2:]
dfm2.reset_index(level=0, inplace=True)

# get cutoff_low from dfm2
d = {}
for i, row in dfm2.iterrows():
    d['t_{}_cutoff_low'.format(i)] = dfm2.at[i,'cutoff_low']
print(d)

for column in dfm.columns[-10:]:
    dfm['{}_low'.format(column)]=dfm['{}'.format(column)].apply(lambda x: 1 if x> d['{}_cutoff_low'.format(column)] else 0)

dfm['datetime'] = pd.to_datetime(df1['year'], errors = 'coerce')

# Create 10 topic model time series datasets
g_1 = dfm.set_index('datetime').resample('A-DEC')['t_0_low'].sum()
g_1 = g_1.reset_index()

g_2 = dfm.set_index('datetime').resample('A-DEC')['t_1_low'].sum()
g_2 = g_2.reset_index()

g_3 = dfm.set_index('datetime').resample('A-DEC')['t_2_low'].sum()
g_3 = g_3.reset_index()

g_4 = dfm.set_index('datetime').resample('A-DEC')['t_3_low'].sum()
g_4 = g_4.reset_index()

g_5 = dfm.set_index('datetime').resample('A-DEC')['t_4_low'].sum()
g_5 = g_5.reset_index()

g_6 = dfm.set_index('datetime').resample('A-DEC')['t_5_low'].sum()
g_6 = g_6.reset_index()

g_7 = dfm.set_index('datetime').resample('A-DEC')['t_6_low'].sum()
g_7 = g_7.reset_index()

g_8 = dfm.set_index('datetime').resample('A-DEC')['t_7_low'].sum()
g_8 = g_8.reset_index()

g_9 = dfm.set_index('datetime').resample('A-DEC')['t_8_low'].sum()
g_9 = g_9.reset_index()

g_10 = dfm.set_index('datetime').resample('A-DEC')['t_9_low'].sum()
g_10 = g_10.reset_index()

# Merge
dfs = [g_1, g_2, g_3, g_4, g_5, g_6, g_7, g_8, g_9, g_10]
from functools import reduce
df_topic_year = reduce(lambda  left,right: pd.merge(left,right,on=['datetime'],
                                            how='left'), dfs)
# Out:
# Collecting pandas==1.2.5
#   Using cached pandas-1.2.5.tar.gz (5.5 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/anaconda3/lib/python3.11/site-packages (from pandas==1.2.5) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /opt/anaconda3/lib/python3.11/site-packages (from pandas==1.2.5) (2023.3.post1)
# Requirement already satisfied: numpy>=1.16.5 in /opt/anaconda3/lib/python3.11/site-packages (from pandas==1.2.5) (1.26.4)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7.3->pandas==1.2.5) (1.16.0)
# Building wheels for collected packages: pandas
#   Building wheel for pandas (pyproject.toml) ... -^C
# anceled
# ERROR: Operation cancelled by user

# %%
# Out:
# Collecting MoreThanSentiments
#   Using cached MoreThanSentiments-0.2.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting tqdm~=4.59.0 (from MoreThanSentiments)
#   Using cached tqdm-4.59.0-py2.py3-none-any.whl.metadata (56 kB)
# Collecting spacy~=3.3.0 (from MoreThanSentiments)
#   Using cached spacy-3.3.3-cp311-cp311-macosx_11_0_arm64.whl
# Collecting pandas~=1.2.4 (from MoreThanSentiments)
#   Using cached pandas-1.2.5.tar.gz (5.5 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting nltk~=3.6.1 (from MoreThanSentiments)
#   Using cached nltk-3.6.7-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: click in /opt/anaconda3/lib/python3.11/site-packages (from nltk~=3.6.1->MoreThanSentiments) (8.1.7)
# Requirement already satisfied: joblib in /opt/anaconda3/lib/python3.11/site-packages (from nltk~=3.6.1->MoreThanSentiments) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /opt/anaconda3/lib/python3.11/site-packages (from nltk~=3.6.1->MoreThanSentiments) (2023.10.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/anaconda3/lib/python3.11/site-packages (from pandas~=1.2.4->MoreThanSentiments) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /opt/anaconda3/lib/python3.11/site-packages (from pandas~=1.2.4->MoreThanSentiments) (2023.3.post1)
# Requirement already satisfied: numpy>=1.16.5 in /opt/anaconda3/lib/python3.11/site-packages (from pandas~=1.2.4->MoreThanSentiments) (1.26.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in /opt/anaconda3/lib/python3.11/site-packages (from spacy~=3.3.0->MoreThanSentiments) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy~=3.3.0->MoreThanSentiments) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy~=3.3.0->MoreThanSentiments) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/anaconda3/lib/python3.11/site-packages (from spacy~=3.3.0->MoreThanSentiments) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/anaconda3/lib/python3.11/site-packages (from spacy~=3.3.0->MoreThanSentiments) (3.0.9)
# Collecting thinc<8.1.0,>=8.0.14 (from spacy~=3.3.0->MoreThanSentiments)
#   Using cached thinc-8.0.17-cp311-cp311-macosx_11_0_arm64.whl
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy~=3.3.0->MoreThanSentiments) (0.7.11)
# Collecting wasabi<1.1.0,>=0.9.1 (from spacy~=3.3.0->MoreThanSentiments)
#   Using cached wasabi-0.10.1-py3-none-any.whl.metadata (28 kB)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /opt/anaconda3/lib/python3.11/site-packages (from spacy~=3.3.0->MoreThanSentiments) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /opt/anaconda3/lib/python3.11/site-packages (from spacy~=3.3.0->MoreThanSentiments) (2.0.10)
# Collecting typer<0.5.0,>=0.3.0 (from spacy~=3.3.0->MoreThanSentiments)
#   Using cached typer-0.4.2-py3-none-any.whl.metadata (12 kB)
# Collecting pathy>=0.3.5 (from spacy~=3.3.0->MoreThanSentiments)
#   Using cached pathy-0.11.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /opt/anaconda3/lib/python3.11/site-packages (from spacy~=3.3.0->MoreThanSentiments) (5.2.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy~=3.3.0->MoreThanSentiments) (2.31.0)
# Collecting pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 (from spacy~=3.3.0->MoreThanSentiments)
#   Using cached pydantic-1.8.2-py3-none-any.whl.metadata (103 kB)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.11/site-packages (from spacy~=3.3.0->MoreThanSentiments) (3.1.3)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.11/site-packages (from spacy~=3.3.0->MoreThanSentiments) (70.0.0)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy~=3.3.0->MoreThanSentiments) (23.1)
# Collecting typing-extensions<4.6.0,>=3.7.4.1 (from spacy~=3.3.0->MoreThanSentiments)
#   Using cached typing_extensions-4.5.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy~=3.3.0->MoreThanSentiments) (3.4.0)
# Requirement already satisfied: language-data>=1.2 in /opt/anaconda3/lib/python3.11/site-packages (from langcodes<4.0.0,>=3.2.0->spacy~=3.3.0->MoreThanSentiments) (1.2.0)
# Collecting pathlib-abc==0.1.1 (from pathy>=0.3.5->spacy~=3.3.0->MoreThanSentiments)
#   Using cached pathlib_abc-0.1.1-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7.3->pandas~=1.2.4->MoreThanSentiments) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy~=3.3.0->MoreThanSentiments) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy~=3.3.0->MoreThanSentiments) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy~=3.3.0->MoreThanSentiments) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy~=3.3.0->MoreThanSentiments) (2024.6.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.11/site-packages (from jinja2->spacy~=3.3.0->MoreThanSentiments) (2.1.3)
# Requirement already satisfied: marisa-trie>=0.7.7 in /opt/anaconda3/lib/python3.11/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy~=3.3.0->MoreThanSentiments) (1.2.0)
# Using cached MoreThanSentiments-0.2.1-py3-none-any.whl (7.3 kB)
# Using cached nltk-3.6.7-py3-none-any.whl (1.5 MB)
# Using cached tqdm-4.59.0-py2.py3-none-any.whl (74 kB)
# Using cached pathy-0.11.0-py3-none-any.whl (47 kB)
# Using cached pathlib_abc-0.1.1-py3-none-any.whl (23 kB)
# Using cached pydantic-1.8.2-py3-none-any.whl (126 kB)
# Using cached typer-0.4.2-py3-none-any.whl (27 kB)
# Using cached typing_extensions-4.5.0-py3-none-any.whl (27 kB)
# Using cached wasabi-0.10.1-py3-none-any.whl (26 kB)
# Building wheels for collected packages: pandas
#   Building wheel for pandas (pyproject.toml) ... error
#   error: subprocess-exited-with-error
#
#   × Building wheel for pandas (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [1501 lines of output]
#       <string>:44: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#       <string>:438: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build/lib.macosx-11.1-arm64-cpython-311
#       creating build/lib.macosx-11.1-arm64-cpython-311/pandas
#       copying pandas/conftest.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas
#       copying pandas/_typing.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas
#       copying pandas/_version.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas
#       copying pandas/__init__.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas
#       copying pandas/_testing.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas
#       copying pandas/testing.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas
#       creating build/lib.macosx-11.1-arm64-cpython-311/pandas/compat
#       copying pandas/compat/_optional.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/compat
#       copying pandas/compat/__init__.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/compat
#       copying pandas/compat/chainmap.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/compat
#       copying pandas/compat/pickle_compat.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/compat
#       creating build/lib.macosx-11.1-arm64-cpython-311/pandas/core
#       copying pandas/core/accessor.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core
#       copying pandas/core/nanops.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core
#       copying pandas/core/missing.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core
#       copying pandas/core/aggregation.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core
#       copying pandas/core/algorithms.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core
#       copying pandas/core/resample.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core
#       copying pandas/core/index.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core
#       copying pandas/core/arraylike.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core
#       copying pandas/core/construction.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core
#       copying pandas/core/config_init.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core
#       copying pandas/core/flags.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core
#       copying pandas/core/generic.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core
#       copying pandas/core/series.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core
#       copying pandas/core/sorting.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core
#       copying pandas/core/__init__.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core
#       copying pandas/core/indexers.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core
#       copying pandas/core/api.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core
#       copying pandas/core/common.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core
#       copying pandas/core/frame.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core
#       copying pandas/core/shared_docs.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core
#       copying pandas/core/indexing.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core
#       copying pandas/core/base.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core
#       copying pandas/core/apply.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core
#       creating build/lib.macosx-11.1-arm64-cpython-311/pandas/util
#       copying pandas/util/_depr_module.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/util
#       copying pandas/util/_test_decorators.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/util
#       copying pandas/util/_validators.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/util
#       copying pandas/util/_print_versions.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/util
#       copying pandas/util/__init__.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/util
#       copying pandas/util/_decorators.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/util
#       copying pandas/util/_doctools.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/util
#       copying pandas/util/testing.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/util
#       copying pandas/util/_exceptions.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/util
#       copying pandas/util/_tester.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/util
#       creating build/lib.macosx-11.1-arm64-cpython-311/pandas/io
#       copying pandas/io/orc.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/io
#       copying pandas/io/feather_format.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/io
#       copying pandas/io/parquet.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/io
#       copying pandas/io/pytables.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/io
#       copying pandas/io/html.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/io
#       copying pandas/io/__init__.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/io
#       copying pandas/io/clipboards.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/io
#       copying pandas/io/parsers.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/io
#       copying pandas/io/api.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/io
#       copying pandas/io/common.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/io
#       copying pandas/io/date_converters.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/io
#       copying pandas/io/pickle.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/io
#       copying pandas/io/sql.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/io
#       copying pandas/io/stata.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/io
#       copying pandas/io/gbq.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/io
#       copying pandas/io/spss.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/io
#       creating build/lib.macosx-11.1-arm64-cpython-311/pandas/tseries
#       copying pandas/tseries/__init__.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tseries
#       copying pandas/tseries/api.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tseries
#       copying pandas/tseries/offsets.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tseries
#       copying pandas/tseries/frequencies.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tseries
#       copying pandas/tseries/holiday.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tseries
#       creating build/lib.macosx-11.1-arm64-cpython-311/pandas/tests
#       copying pandas/tests/test_optional_dependency.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests
#       copying pandas/tests/test_expressions.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests
#       copying pandas/tests/test_register_accessor.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests
#       copying pandas/tests/test_common.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests
#       copying pandas/tests/test_downstream.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests
#       copying pandas/tests/test_errors.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests
#       copying pandas/tests/test_sorting.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests
#       copying pandas/tests/test_aggregation.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests
#       copying pandas/tests/__init__.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests
#       copying pandas/tests/test_nanops.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests
#       copying pandas/tests/test_take.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests
#       copying pandas/tests/test_algos.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests
#       copying pandas/tests/test_multilevel.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests
#       copying pandas/tests/test_flags.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests
#       copying pandas/tests/test_strings.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests
#       creating build/lib.macosx-11.1-arm64-cpython-311/pandas/_libs
#       copying pandas/_libs/__init__.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/_libs
#       creating build/lib.macosx-11.1-arm64-cpython-311/pandas/plotting
#       copying pandas/plotting/__init__.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/plotting
#       copying pandas/plotting/_core.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/plotting
#       copying pandas/plotting/_misc.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/plotting
#       creating build/lib.macosx-11.1-arm64-cpython-311/pandas/arrays
#       copying pandas/arrays/__init__.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/arrays
#       creating build/lib.macosx-11.1-arm64-cpython-311/pandas/api
#       copying pandas/api/__init__.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/api
#       creating build/lib.macosx-11.1-arm64-cpython-311/pandas/errors
#       copying pandas/errors/__init__.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/errors
#       creating build/lib.macosx-11.1-arm64-cpython-311/pandas/_config
#       copying pandas/_config/config.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/_config
#       copying pandas/_config/__init__.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/_config
#       copying pandas/_config/display.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/_config
#       copying pandas/_config/localization.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/_config
#       copying pandas/_config/dates.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/_config
#       creating build/lib.macosx-11.1-arm64-cpython-311/pandas/compat/numpy
#       copying pandas/compat/numpy/__init__.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/compat/numpy
#       copying pandas/compat/numpy/function.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/compat/numpy
#       creating build/lib.macosx-11.1-arm64-cpython-311/pandas/core/reshape
#       copying pandas/core/reshape/tile.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/reshape
#       copying pandas/core/reshape/merge.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/reshape
#       copying pandas/core/reshape/concat.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/reshape
#       copying pandas/core/reshape/util.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/reshape
#       copying pandas/core/reshape/reshape.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/reshape
#       copying pandas/core/reshape/__init__.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/reshape
#       copying pandas/core/reshape/api.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/reshape
#       copying pandas/core/reshape/melt.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/reshape
#       copying pandas/core/reshape/pivot.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/reshape
#       creating build/lib.macosx-11.1-arm64-cpython-311/pandas/core/strings
#       copying pandas/core/strings/accessor.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/strings
#       copying pandas/core/strings/object_array.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/strings
#       copying pandas/core/strings/__init__.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/strings
#       copying pandas/core/strings/base.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/strings
#       creating build/lib.macosx-11.1-arm64-cpython-311/pandas/core/tools
#       copying pandas/core/tools/timedeltas.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/tools
#       copying pandas/core/tools/datetimes.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/tools
#       copying pandas/core/tools/__init__.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/tools
#       copying pandas/core/tools/times.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/tools
#       copying pandas/core/tools/numeric.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/tools
#       creating build/lib.macosx-11.1-arm64-cpython-311/pandas/core/util
#       copying pandas/core/util/__init__.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/util
#       copying pandas/core/util/hashing.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/util
#       copying pandas/core/util/numba_.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/util
#       creating build/lib.macosx-11.1-arm64-cpython-311/pandas/core/array_algos
#       copying pandas/core/array_algos/transforms.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/array_algos
#       copying pandas/core/array_algos/__init__.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/array_algos
#       copying pandas/core/array_algos/masked_reductions.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/array_algos
#       copying pandas/core/array_algos/replace.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/array_algos
#       creating build/lib.macosx-11.1-arm64-cpython-311/pandas/core/dtypes
#       copying pandas/core/dtypes/cast.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/dtypes
#       copying pandas/core/dtypes/missing.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/dtypes
#       copying pandas/core/dtypes/concat.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/dtypes
#       copying pandas/core/dtypes/generic.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/dtypes
#       copying pandas/core/dtypes/__init__.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/dtypes
#       copying pandas/core/dtypes/dtypes.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/dtypes
#       copying pandas/core/dtypes/api.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/dtypes
#       copying pandas/core/dtypes/common.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/dtypes
#       copying pandas/core/dtypes/inference.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/dtypes
#       copying pandas/core/dtypes/base.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/dtypes
#       creating build/lib.macosx-11.1-arm64-cpython-311/pandas/core/groupby
#       copying pandas/core/groupby/categorical.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/groupby
#       copying pandas/core/groupby/generic.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/groupby
#       copying pandas/core/groupby/__init__.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/groupby
#       copying pandas/core/groupby/ops.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/groupby
#       copying pandas/core/groupby/grouper.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/groupby
#       copying pandas/core/groupby/groupby.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/groupby
#       copying pandas/core/groupby/numba_.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/groupby
#       copying pandas/core/groupby/base.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/groupby
#       creating build/lib.macosx-11.1-arm64-cpython-311/pandas/core/internals
#       copying pandas/core/internals/concat.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/internals
#       copying pandas/core/internals/construction.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/internals
#       copying pandas/core/internals/__init__.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/internals
#       copying pandas/core/internals/ops.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/internals
#       copying pandas/core/internals/blocks.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/internals
#       copying pandas/core/internals/managers.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/internals
#       creating build/lib.macosx-11.1-arm64-cpython-311/pandas/core/computation
#       copying pandas/core/computation/parsing.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/computation
#       copying pandas/core/computation/check.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/computation
#       copying pandas/core/computation/align.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/computation
#       copying pandas/core/computation/pytables.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/computation
#       copying pandas/core/computation/engines.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/computation
#       copying pandas/core/computation/expressions.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/computation
#       copying pandas/core/computation/__init__.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/computation
#       copying pandas/core/computation/api.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/computation
#       copying pandas/core/computation/ops.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/computation
#       copying pandas/core/computation/common.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/computation
#       copying pandas/core/computation/eval.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/computation
#       copying pandas/core/computation/scope.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/computation
#       copying pandas/core/computation/expr.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/computation
#       creating build/lib.macosx-11.1-arm64-cpython-311/pandas/core/window
#       copying pandas/core/window/ewm.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/window
#       copying pandas/core/window/__init__.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/window
#       copying pandas/core/window/rolling.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/window
#       copying pandas/core/window/indexers.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/window
#       copying pandas/core/window/common.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/window
#       copying pandas/core/window/numba_.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/window
#       copying pandas/core/window/expanding.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/window
#       creating build/lib.macosx-11.1-arm64-cpython-311/pandas/core/arrays
#       copying pandas/core/arrays/floating.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/arrays
#       copying pandas/core/arrays/categorical.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/arrays
#       copying pandas/core/arrays/_arrow_utils.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/arrays
#       copying pandas/core/arrays/interval.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/arrays
#       copying pandas/core/arrays/timedeltas.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/arrays
#       copying pandas/core/arrays/datetimes.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/arrays
#       copying pandas/core/arrays/string_.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/arrays
#       copying pandas/core/arrays/__init__.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/arrays
#       copying pandas/core/arrays/numpy_.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/arrays
#       copying pandas/core/arrays/_ranges.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/arrays
#       copying pandas/core/arrays/string_arrow.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/arrays
#       copying pandas/core/arrays/boolean.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/arrays
#       copying pandas/core/arrays/integer.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/arrays
#       copying pandas/core/arrays/masked.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/arrays
#       copying pandas/core/arrays/period.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/arrays
#       copying pandas/core/arrays/numeric.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/arrays
#       copying pandas/core/arrays/datetimelike.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/arrays
#       copying pandas/core/arrays/base.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/arrays
#       copying pandas/core/arrays/_mixins.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/arrays
#       creating build/lib.macosx-11.1-arm64-cpython-311/pandas/core/ops
#       copying pandas/core/ops/array_ops.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/ops
#       copying pandas/core/ops/roperator.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/ops
#       copying pandas/core/ops/missing.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/ops
#       copying pandas/core/ops/methods.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/ops
#       copying pandas/core/ops/dispatch.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/ops
#       copying pandas/core/ops/invalid.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/ops
#       copying pandas/core/ops/__init__.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/ops
#       copying pandas/core/ops/docstrings.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/ops
#       copying pandas/core/ops/mask_ops.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/ops
#       copying pandas/core/ops/common.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/ops
#       creating build/lib.macosx-11.1-arm64-cpython-311/pandas/core/sparse
#       copying pandas/core/sparse/__init__.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/sparse
#       copying pandas/core/sparse/api.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/sparse
#       creating build/lib.macosx-11.1-arm64-cpython-311/pandas/core/indexes
#       copying pandas/core/indexes/accessors.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/indexes
#       copying pandas/core/indexes/interval.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/indexes
#       copying pandas/core/indexes/timedeltas.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/indexes
#       copying pandas/core/indexes/range.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/indexes
#       copying pandas/core/indexes/datetimes.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/indexes
#       copying pandas/core/indexes/multi.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/indexes
#       copying pandas/core/indexes/__init__.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/indexes
#       copying pandas/core/indexes/api.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/indexes
#       copying pandas/core/indexes/period.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/indexes
#       copying pandas/core/indexes/frozen.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/indexes
#       copying pandas/core/indexes/extension.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/indexes
#       copying pandas/core/indexes/numeric.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/indexes
#       copying pandas/core/indexes/datetimelike.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/indexes
#       copying pandas/core/indexes/base.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/indexes
#       copying pandas/core/indexes/category.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/indexes
#       creating build/lib.macosx-11.1-arm64-cpython-311/pandas/core/arrays/sparse
#       copying pandas/core/arrays/sparse/accessor.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/arrays/sparse
#       copying pandas/core/arrays/sparse/scipy_sparse.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/arrays/sparse
#       copying pandas/core/arrays/sparse/dtype.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/arrays/sparse
#       copying pandas/core/arrays/sparse/__init__.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/arrays/sparse
#       copying pandas/core/arrays/sparse/array.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/core/arrays/sparse
#       creating build/lib.macosx-11.1-arm64-cpython-311/pandas/io/formats
#       copying pandas/io/formats/console.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/io/formats
#       copying pandas/io/formats/style.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/io/formats
#       copying pandas/io/formats/html.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/io/formats
#       copying pandas/io/formats/__init__.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/io/formats
#       copying pandas/io/formats/format.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/io/formats
#       copying pandas/io/formats/excel.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/io/formats
#       copying pandas/io/formats/css.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/io/formats
#       copying pandas/io/formats/_color_data.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/io/formats
#       copying pandas/io/formats/csvs.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/io/formats
#       copying pandas/io/formats/string.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/io/formats
#       copying pandas/io/formats/info.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/io/formats
#       copying pandas/io/formats/latex.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/io/formats
#       copying pandas/io/formats/printing.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/io/formats
#       creating build/lib.macosx-11.1-arm64-cpython-311/pandas/io/excel
#       copying pandas/io/excel/_openpyxl.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/io/excel
#       copying pandas/io/excel/_base.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/io/excel
#       copying pandas/io/excel/_xlrd.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/io/excel
#       copying pandas/io/excel/__init__.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/io/excel
#       copying pandas/io/excel/_pyxlsb.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/io/excel
#       copying pandas/io/excel/_odswriter.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/io/excel
#       copying pandas/io/excel/_util.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/io/excel
#       copying pandas/io/excel/_odfreader.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/io/excel
#       copying pandas/io/excel/_xlwt.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/io/excel
#       copying pandas/io/excel/_xlsxwriter.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/io/excel
#       creating build/lib.macosx-11.1-arm64-cpython-311/pandas/io/json
#       copying pandas/io/json/_json.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/io/json
#       copying pandas/io/json/_normalize.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/io/json
#       copying pandas/io/json/_table_schema.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/io/json
#       copying pandas/io/json/__init__.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/io/json
#       creating build/lib.macosx-11.1-arm64-cpython-311/pandas/io/sas
#       copying pandas/io/sas/sas7bdat.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/io/sas
#       copying pandas/io/sas/sas_constants.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/io/sas
#       copying pandas/io/sas/sasreader.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/io/sas
#       copying pandas/io/sas/__init__.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/io/sas
#       copying pandas/io/sas/sas_xport.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/io/sas
#       creating build/lib.macosx-11.1-arm64-cpython-311/pandas/io/clipboard
#       copying pandas/io/clipboard/__init__.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/io/clipboard
#       creating build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/series
#       copying pandas/tests/series/test_logical_ops.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/series
#       copying pandas/tests/series/test_reductions.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/series
#       copying pandas/tests/series/test_constructors.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/series
#       copying pandas/tests/series/test_missing.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/series
#       copying pandas/tests/series/test_unary.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/series
#       copying pandas/tests/series/test_cumulative.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/series
#       copying pandas/tests/series/__init__.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/series
#       copying pandas/tests/series/test_subclass.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/series
#       copying pandas/tests/series/test_repr.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/series
#       copying pandas/tests/series/test_iteration.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/series
#       copying pandas/tests/series/test_ufunc.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/series
#       copying pandas/tests/series/test_validate.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/series
#       copying pandas/tests/series/test_duplicates.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/series
#       copying pandas/tests/series/test_npfuncs.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/series
#       copying pandas/tests/series/test_api.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/series
#       copying pandas/tests/series/test_arithmetic.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/series
#       copying pandas/tests/series/test_dtypes.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/series
#       creating build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/reshape
#       copying pandas/tests/reshape/test_pivot_multilevel.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/reshape
#       copying pandas/tests/reshape/test_cut.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/reshape
#       copying pandas/tests/reshape/test_get_dummies.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/reshape
#       copying pandas/tests/reshape/test_union_categoricals.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/reshape
#       copying pandas/tests/reshape/test_qcut.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/reshape
#       copying pandas/tests/reshape/__init__.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/reshape
#       copying pandas/tests/reshape/test_pivot.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/reshape
#       copying pandas/tests/reshape/test_util.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/reshape
#       copying pandas/tests/reshape/test_melt.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/reshape
#       copying pandas/tests/reshape/test_crosstab.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/reshape
#       creating build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/tools
#       copying pandas/tests/tools/test_to_time.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/tools
#       copying pandas/tests/tools/__init__.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/tools
#       copying pandas/tests/tools/test_to_timedelta.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/tools
#       copying pandas/tests/tools/test_to_datetime.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/tools
#       copying pandas/tests/tools/test_to_numeric.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/tools
#       creating build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/extension
#       copying pandas/tests/extension/test_external_block.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/extension
#       copying pandas/tests/extension/test_period.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/extension
#       copying pandas/tests/extension/conftest.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/extension
#       copying pandas/tests/extension/test_common.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/extension
#       copying pandas/tests/extension/test_sparse.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/extension
#       copying pandas/tests/extension/test_floating.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/extension
#       copying pandas/tests/extension/test_string.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/extension
#       copying pandas/tests/extension/test_categorical.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/extension
#       copying pandas/tests/extension/test_boolean.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/extension
#       copying pandas/tests/extension/__init__.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/extension
#       copying pandas/tests/extension/test_interval.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/extension
#       copying pandas/tests/extension/test_datetime.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/extension
#       copying pandas/tests/extension/test_integer.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/extension
#       copying pandas/tests/extension/test_numpy.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/extension
#       creating build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/resample
#       copying pandas/tests/resample/conftest.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/resample
#       copying pandas/tests/resample/test_resampler_grouper.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/resample
#       copying pandas/tests/resample/__init__.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/resample
#       copying pandas/tests/resample/test_timedelta.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/resample
#       copying pandas/tests/resample/test_deprecated.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/resample
#       copying pandas/tests/resample/test_period_index.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/resample
#       copying pandas/tests/resample/test_datetime_index.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/resample
#       copying pandas/tests/resample/test_base.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/resample
#       copying pandas/tests/resample/test_time_grouper.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/resample
#       copying pandas/tests/resample/test_resample_api.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/resample
#       creating build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/util
#       copying pandas/tests/util/test_deprecate_nonkeyword_arguments.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/util
#       copying pandas/tests/util/test_validate_args_and_kwargs.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/util
#       copying pandas/tests/util/test_assert_series_equal.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/util
#       copying pandas/tests/util/conftest.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/util
#       copying pandas/tests/util/test_safe_import.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/util
#       copying pandas/tests/util/test_assert_frame_equal.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/util
#       copying pandas/tests/util/test_show_versions.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/util
#       copying pandas/tests/util/test_assert_interval_array_equal.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/util
#       copying pandas/tests/util/__init__.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/util
#       copying pandas/tests/util/test_util.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/util
#       copying pandas/tests/util/test_assert_index_equal.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/util
#       copying pandas/tests/util/test_validate_args.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/util
#       copying pandas/tests/util/test_validate_kwargs.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/util
#       copying pandas/tests/util/test_assert_categorical_equal.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/util
#       copying pandas/tests/util/test_assert_numpy_array_equal.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/util
#       copying pandas/tests/util/test_assert_extension_array_equal.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/util
#       copying pandas/tests/util/test_deprecate.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/util
#       copying pandas/tests/util/test_hashing.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/util
#       copying pandas/tests/util/test_assert_produces_warning.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/util
#       copying pandas/tests/util/test_numba.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/util
#       copying pandas/tests/util/test_doc.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/util
#       copying pandas/tests/util/test_deprecate_kwarg.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/util
#       copying pandas/tests/util/test_assert_almost_equal.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/util
#       creating build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/config
#       copying pandas/tests/config/test_localization.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/config
#       copying pandas/tests/config/__init__.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/config
#       copying pandas/tests/config/test_config.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/config
#       creating build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/io
#       copying pandas/tests/io/test_parquet.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/io
#       copying pandas/tests/io/test_fsspec.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/io
#       copying pandas/tests/io/test_compression.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/io
#       copying pandas/tests/io/test_date_converters.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/io
#       copying pandas/tests/io/conftest.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/io
#       copying pandas/tests/io/test_common.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/io
#       copying pandas/tests/io/test_pickle.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/io
#       copying pandas/tests/io/test_orc.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/io
#       copying pandas/tests/io/test_clipboard.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/io
#       copying pandas/tests/io/__init__.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/io
#       copying pandas/tests/io/test_stata.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/io
#       copying pandas/tests/io/test_html.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/io
#       copying pandas/tests/io/test_gcs.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/io
#       copying pandas/tests/io/test_sql.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/io
#       copying pandas/tests/io/test_gbq.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/io
#       copying pandas/tests/io/test_feather.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/io
#       copying pandas/tests/io/test_spss.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/io
#       copying pandas/tests/io/generate_legacy_storage_files.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/io
#       copying pandas/tests/io/test_s3.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/io
#       creating build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/tseries
#       copying pandas/tests/tseries/__init__.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/tseries
#       creating build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/frame
#       copying pandas/tests/frame/test_block_internals.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/frame
#       copying pandas/tests/frame/test_alter_axes.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/frame
#       copying pandas/tests/frame/test_logical_ops.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/frame
#       copying pandas/tests/frame/conftest.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/frame
#       copying pandas/tests/frame/test_reductions.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/frame
#       copying pandas/tests/frame/test_constructors.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/frame
#       copying pandas/tests/frame/test_query_eval.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/frame
#       copying pandas/tests/frame/test_unary.py -> build/lib.macosx-11.1-arm64-cpython-311/pandas/tests/frame
# ...
#       clang -bundle -undefined dynamic_lookup -Wl,-rpath,/opt/anaconda3/lib -L/opt/anaconda3/lib -Wl,-rpath,/opt/anaconda3/lib -L/opt/anaconda3/lib build/temp.macosx-11.1-arm64-cpython-311/pandas/_libs/tslibs/timestamps.o -o build/lib.macosx-11.1-arm64-cpython-311/pandas/_libs/tslibs/timestamps.cpython-311-darwin.so
#       ld: warning: duplicate -rpath '/opt/anaconda3/lib' ignored
#       building 'pandas._libs.tslibs.timezones' extension
#       clang -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/anaconda3/include -arch arm64 -fPIC -O2 -isystem /opt/anaconda3/include -arch arm64 -DNPY_NO_DEPRECATED_API=0 -I/private/var/folders/vh/s7vr2c1n3vn041536pmsqsj40000gn/T/pip-build-env-7eo_zy84/overlay/lib/python3.11/site-packages/numpy/_core/include -I/opt/anaconda3/include/python3.11 -c pandas/_libs/tslibs/timezones.c -o build/temp.macosx-11.1-arm64-cpython-311/pandas/_libs/tslibs/timezones.o -Wno-error=unreachable-code
#       clang -bundle -undefined dynamic_lookup -Wl,-rpath,/opt/anaconda3/lib -L/opt/anaconda3/lib -Wl,-rpath,/opt/anaconda3/lib -L/opt/anaconda3/lib build/temp.macosx-11.1-arm64-cpython-311/pandas/_libs/tslibs/timezones.o -o build/lib.macosx-11.1-arm64-cpython-311/pandas/_libs/tslibs/timezones.cpython-311-darwin.so
#       ld: warning: duplicate -rpath '/opt/anaconda3/lib' ignored
#       building 'pandas._libs.tslibs.tzconversion' extension
#       clang -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/anaconda3/include -arch arm64 -fPIC -O2 -isystem /opt/anaconda3/include -arch arm64 -DNPY_NO_DEPRECATED_API=0 -I./pandas/_libs/tslibs -Ipandas/_libs/tslibs -I/private/var/folders/vh/s7vr2c1n3vn041536pmsqsj40000gn/T/pip-build-env-7eo_zy84/overlay/lib/python3.11/site-packages/numpy/_core/include -I/opt/anaconda3/include/python3.11 -c pandas/_libs/tslibs/tzconversion.c -o build/temp.macosx-11.1-arm64-cpython-311/pandas/_libs/tslibs/tzconversion.o -Wno-error=unreachable-code
#       clang -bundle -undefined dynamic_lookup -Wl,-rpath,/opt/anaconda3/lib -L/opt/anaconda3/lib -Wl,-rpath,/opt/anaconda3/lib -L/opt/anaconda3/lib build/temp.macosx-11.1-arm64-cpython-311/pandas/_libs/tslibs/tzconversion.o -o build/lib.macosx-11.1-arm64-cpython-311/pandas/_libs/tslibs/tzconversion.cpython-311-darwin.so
#       ld: warning: duplicate -rpath '/opt/anaconda3/lib' ignored
#       building 'pandas._libs.tslibs.vectorized' extension
#       clang -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/anaconda3/include -arch arm64 -fPIC -O2 -isystem /opt/anaconda3/include -arch arm64 -DNPY_NO_DEPRECATED_API=0 -I./pandas/_libs/tslibs -Ipandas/_libs/tslibs -I/private/var/folders/vh/s7vr2c1n3vn041536pmsqsj40000gn/T/pip-build-env-7eo_zy84/overlay/lib/python3.11/site-packages/numpy/_core/include -I/opt/anaconda3/include/python3.11 -c pandas/_libs/tslibs/vectorized.c -o build/temp.macosx-11.1-arm64-cpython-311/pandas/_libs/tslibs/vectorized.o -Wno-error=unreachable-code
#       clang -bundle -undefined dynamic_lookup -Wl,-rpath,/opt/anaconda3/lib -L/opt/anaconda3/lib -Wl,-rpath,/opt/anaconda3/lib -L/opt/anaconda3/lib build/temp.macosx-11.1-arm64-cpython-311/pandas/_libs/tslibs/vectorized.o -o build/lib.macosx-11.1-arm64-cpython-311/pandas/_libs/tslibs/vectorized.cpython-311-darwin.so
#       ld: warning: duplicate -rpath '/opt/anaconda3/lib' ignored
#       building 'pandas._libs.testing' extension
#       clang -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/anaconda3/include -arch arm64 -fPIC -O2 -isystem /opt/anaconda3/include -arch arm64 -DNPY_NO_DEPRECATED_API=0 -I./pandas/_libs -I/private/var/folders/vh/s7vr2c1n3vn041536pmsqsj40000gn/T/pip-build-env-7eo_zy84/overlay/lib/python3.11/site-packages/numpy/_core/include -I/opt/anaconda3/include/python3.11 -c pandas/_libs/testing.c -o build/temp.macosx-11.1-arm64-cpython-311/pandas/_libs/testing.o -Wno-error=unreachable-code
#       clang -bundle -undefined dynamic_lookup -Wl,-rpath,/opt/anaconda3/lib -L/opt/anaconda3/lib -Wl,-rpath,/opt/anaconda3/lib -L/opt/anaconda3/lib build/temp.macosx-11.1-arm64-cpython-311/pandas/_libs/testing.o -o build/lib.macosx-11.1-arm64-cpython-311/pandas/_libs/testing.cpython-311-darwin.so
#       ld: warning: duplicate -rpath '/opt/anaconda3/lib' ignored
#       building 'pandas._libs.window.aggregations' extension
#       creating build/temp.macosx-11.1-arm64-cpython-311/pandas/_libs/window
#       clang -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/anaconda3/include -arch arm64 -fPIC -O2 -isystem /opt/anaconda3/include -arch arm64 -DNPY_NO_DEPRECATED_API=0 -Ipandas/_libs/window -I./pandas/_libs -I/private/var/folders/vh/s7vr2c1n3vn041536pmsqsj40000gn/T/pip-build-env-7eo_zy84/overlay/lib/python3.11/site-packages/numpy/_core/include -I/opt/anaconda3/include/python3.11 -c pandas/_libs/window/aggregations.cpp -o build/temp.macosx-11.1-arm64-cpython-311/pandas/_libs/window/aggregations.o -Wno-error=unreachable-code
#       clang++ -bundle -undefined dynamic_lookup -Wl,-rpath,/opt/anaconda3/lib -L/opt/anaconda3/lib -Wl,-rpath,/opt/anaconda3/lib -L/opt/anaconda3/lib build/temp.macosx-11.1-arm64-cpython-311/pandas/_libs/window/aggregations.o -o build/lib.macosx-11.1-arm64-cpython-311/pandas/_libs/window/aggregations.cpython-311-darwin.so
#       ld: warning: duplicate -rpath '/opt/anaconda3/lib' ignored
#       building 'pandas._libs.window.indexers' extension
#       clang -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/anaconda3/include -arch arm64 -fPIC -O2 -isystem /opt/anaconda3/include -arch arm64 -DNPY_NO_DEPRECATED_API=0 -I/private/var/folders/vh/s7vr2c1n3vn041536pmsqsj40000gn/T/pip-build-env-7eo_zy84/overlay/lib/python3.11/site-packages/numpy/_core/include -I/opt/anaconda3/include/python3.11 -c pandas/_libs/window/indexers.c -o build/temp.macosx-11.1-arm64-cpython-311/pandas/_libs/window/indexers.o -Wno-error=unreachable-code
#       clang -bundle -undefined dynamic_lookup -Wl,-rpath,/opt/anaconda3/lib -L/opt/anaconda3/lib -Wl,-rpath,/opt/anaconda3/lib -L/opt/anaconda3/lib build/temp.macosx-11.1-arm64-cpython-311/pandas/_libs/window/indexers.o -o build/lib.macosx-11.1-arm64-cpython-311/pandas/_libs/window/indexers.cpython-311-darwin.so
#       ld: warning: duplicate -rpath '/opt/anaconda3/lib' ignored
#       building 'pandas._libs.writers' extension
#       clang -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/anaconda3/include -arch arm64 -fPIC -O2 -isystem /opt/anaconda3/include -arch arm64 -DNPY_NO_DEPRECATED_API=0 -I/private/var/folders/vh/s7vr2c1n3vn041536pmsqsj40000gn/T/pip-build-env-7eo_zy84/overlay/lib/python3.11/site-packages/numpy/_core/include -I/opt/anaconda3/include/python3.11 -c pandas/_libs/writers.c -o build/temp.macosx-11.1-arm64-cpython-311/pandas/_libs/writers.o -Wno-error=unreachable-code
#       clang -bundle -undefined dynamic_lookup -Wl,-rpath,/opt/anaconda3/lib -L/opt/anaconda3/lib -Wl,-rpath,/opt/anaconda3/lib -L/opt/anaconda3/lib build/temp.macosx-11.1-arm64-cpython-311/pandas/_libs/writers.o -o build/lib.macosx-11.1-arm64-cpython-311/pandas/_libs/writers.cpython-311-darwin.so
#       ld: warning: duplicate -rpath '/opt/anaconda3/lib' ignored
#       building 'pandas.io.sas._sas' extension
#       creating build/temp.macosx-11.1-arm64-cpython-311/pandas/io
#       creating build/temp.macosx-11.1-arm64-cpython-311/pandas/io/sas
#       clang -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/anaconda3/include -arch arm64 -fPIC -O2 -isystem /opt/anaconda3/include -arch arm64 -DNPY_NO_DEPRECATED_API=0 -I/private/var/folders/vh/s7vr2c1n3vn041536pmsqsj40000gn/T/pip-build-env-7eo_zy84/overlay/lib/python3.11/site-packages/numpy/_core/include -I/opt/anaconda3/include/python3.11 -c pandas/io/sas/sas.c -o build/temp.macosx-11.1-arm64-cpython-311/pandas/io/sas/sas.o -Wno-error=unreachable-code
#       clang -bundle -undefined dynamic_lookup -Wl,-rpath,/opt/anaconda3/lib -L/opt/anaconda3/lib -Wl,-rpath,/opt/anaconda3/lib -L/opt/anaconda3/lib build/temp.macosx-11.1-arm64-cpython-311/pandas/io/sas/sas.o -o build/lib.macosx-11.1-arm64-cpython-311/pandas/io/sas/_sas.cpython-311-darwin.so
#       ld: warning: duplicate -rpath '/opt/anaconda3/lib' ignored
#       building 'pandas._libs.json' extension
#       creating build/temp.macosx-11.1-arm64-cpython-311/pandas/_libs/src/ujson
#       creating build/temp.macosx-11.1-arm64-cpython-311/pandas/_libs/src/ujson/lib
#       creating build/temp.macosx-11.1-arm64-cpython-311/pandas/_libs/src/ujson/python
#       clang -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/anaconda3/include -arch arm64 -fPIC -O2 -isystem /opt/anaconda3/include -arch arm64 -DNPY_NO_DEPRECATED_API=0 -Ipandas/_libs/src/ujson/python -Ipandas/_libs/src/ujson/lib -Ipandas/_libs/src/datetime -I/private/var/folders/vh/s7vr2c1n3vn041536pmsqsj40000gn/T/pip-build-env-7eo_zy84/overlay/lib/python3.11/site-packages/numpy/_core/include -I/opt/anaconda3/include/python3.11 -c pandas/_libs/src/ujson/lib/ultrajsondec.c -o build/temp.macosx-11.1-arm64-cpython-311/pandas/_libs/src/ujson/lib/ultrajsondec.o -D_GNU_SOURCE -Wno-error=unreachable-code
#       pandas/_libs/src/ujson/lib/ultrajsondec.c:119:9: warning: variable 'mantSize' set but not used [-Wunused-but-set-variable]
#           int mantSize = 0;
#               ^
#       1 warning generated.
#       clang -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/anaconda3/include -arch arm64 -fPIC -O2 -isystem /opt/anaconda3/include -arch arm64 -DNPY_NO_DEPRECATED_API=0 -Ipandas/_libs/src/ujson/python -Ipandas/_libs/src/ujson/lib -Ipandas/_libs/src/datetime -I/private/var/folders/vh/s7vr2c1n3vn041536pmsqsj40000gn/T/pip-build-env-7eo_zy84/overlay/lib/python3.11/site-packages/numpy/_core/include -I/opt/anaconda3/include/python3.11 -c pandas/_libs/src/ujson/lib/ultrajsonenc.c -o build/temp.macosx-11.1-arm64-cpython-311/pandas/_libs/src/ujson/lib/ultrajsonenc.o -D_GNU_SOURCE -Wno-error=unreachable-code
#       clang -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/anaconda3/include -arch arm64 -fPIC -O2 -isystem /opt/anaconda3/include -arch arm64 -DNPY_NO_DEPRECATED_API=0 -Ipandas/_libs/src/ujson/python -Ipandas/_libs/src/ujson/lib -Ipandas/_libs/src/datetime -I/private/var/folders/vh/s7vr2c1n3vn041536pmsqsj40000gn/T/pip-build-env-7eo_zy84/overlay/lib/python3.11/site-packages/numpy/_core/include -I/opt/anaconda3/include/python3.11 -c pandas/_libs/src/ujson/python/JSONtoObj.c -o build/temp.macosx-11.1-arm64-cpython-311/pandas/_libs/src/ujson/python/JSONtoObj.o -D_GNU_SOURCE -Wno-error=unreachable-code
#       pandas/_libs/src/ujson/python/JSONtoObj.c:195:49: warning: incompatible pointer types passing 'PyObject *' (aka 'struct _object *') to parameter of type 'const PyArrayObject *' (aka 'const struct tagPyArrayObject_fields *') [-Wincompatible-pointer-types]
#               new_data = PyDataMem_RENEW(PyArray_DATA(ret), i * npyarr->elsize);
#                                                       ^~~
#       /private/var/folders/vh/s7vr2c1n3vn041536pmsqsj40000gn/T/pip-build-env-7eo_zy84/overlay/lib/python3.11/site-packages/numpy/_core/include/numpy/ndarraytypes.h:1508:35: note: passing argument to parameter 'arr' here
#       PyArray_DATA(const PyArrayObject *arr)
#                                         ^
#       pandas/_libs/src/ujson/python/JSONtoObj.c:260:33: error: no member named 'elsize' in 'struct _PyArray_Descr'
#               npyarr->elsize = dtype->elsize;
#                                ~~~~~  ^
#       pandas/_libs/src/ujson/python/JSONtoObj.c:305:53: warning: incompatible pointer types passing 'PyObject *' (aka 'struct _object *') to parameter of type 'const PyArrayObject *' (aka 'const struct tagPyArrayObject_fields *') [-Wincompatible-pointer-types]
#                   new_data = PyDataMem_RENEW(PyArray_DATA(npyarr->ret),
#                                                           ^~~~~~~~~~~
#       /private/var/folders/vh/s7vr2c1n3vn041536pmsqsj40000gn/T/pip-build-env-7eo_zy84/overlay/lib/python3.11/site-packages/numpy/_core/include/numpy/ndarraytypes.h:1508:35: note: passing argument to parameter 'arr' here
#       PyArray_DATA(const PyArrayObject *arr)
#                                         ^
#       pandas/_libs/src/ujson/python/JSONtoObj.c:316:18: warning: incompatible pointer types passing 'PyObject *' (aka 'struct _object *') to parameter of type 'const PyArrayObject *' (aka 'const struct tagPyArrayObject_fields *') [-Wincompatible-pointer-types]
#           PyArray_DIMS(npyarr->ret)[0] = i + 1;
#                        ^~~~~~~~~~~
#       /private/var/folders/vh/s7vr2c1n3vn041536pmsqsj40000gn/T/pip-build-env-7eo_zy84/overlay/lib/python3.11/site-packages/numpy/_core/include/numpy/ndarraytypes.h:1520:35: note: passing argument to parameter 'arr' here
#       PyArray_DIMS(const PyArrayObject *arr)
#                                         ^
#       pandas/_libs/src/ujson/python/JSONtoObj.c:318:33: warning: incompatible pointer types passing 'PyObject *' (aka 'struct _object *') to parameter of type 'const PyArrayObject *' (aka 'const struct tagPyArrayObject_fields *') [-Wincompatible-pointer-types]
#           if ((item = PyArray_GETPTR1(npyarr->ret, i)) == NULL ||
#                                       ^~~~~~~~~~~
#       /private/var/folders/vh/s7vr2c1n3vn041536pmsqsj40000gn/T/pip-build-env-7eo_zy84/overlay/lib/python3.11/site-packages/numpy/_core/include/numpy/ndarrayobject.h:138:57: note: expanded from macro 'PyArray_GETPTR1'
#       #define PyArray_GETPTR1(obj, i) ((void *)(PyArray_BYTES(obj) + \
#                                                               ^~~
#       /private/var/folders/vh/s7vr2c1n3vn041536pmsqsj40000gn/T/pip-build-env-7eo_zy84/overlay/lib/python3.11/site-packages/numpy/_core/include/numpy/ndarraytypes.h:1514:36: note: passing argument to parameter 'arr' here
#       PyArray_BYTES(const PyArrayObject *arr)
#                                          ^
#       pandas/_libs/src/ujson/python/JSONtoObj.c:318:33: warning: incompatible pointer types passing 'PyObject *' (aka 'struct _object *') to parameter of type 'const PyArrayObject *' (aka 'const struct tagPyArrayObject_fields *') [-Wincompatible-pointer-types]
#           if ((item = PyArray_GETPTR1(npyarr->ret, i)) == NULL ||
#                                       ^~~~~~~~~~~
#       /private/var/folders/vh/s7vr2c1n3vn041536pmsqsj40000gn/T/pip-build-env-7eo_zy84/overlay/lib/python3.11/site-packages/numpy/_core/include/numpy/ndarrayobject.h:139:62: note: expanded from macro 'PyArray_GETPTR1'
#                                                (i)*PyArray_STRIDES(obj)[0]))
#                                                                    ^~~
#       /private/var/folders/vh/s7vr2c1n3vn041536pmsqsj40000gn/T/pip-build-env-7eo_zy84/overlay/lib/python3.11/site-packages/numpy/_core/include/numpy/ndarraytypes.h:1526:38: note: passing argument to parameter 'arr' here
#       PyArray_STRIDES(const PyArrayObject *arr)
#                                            ^
#       pandas/_libs/src/ujson/python/JSONtoObj.c:319:25: warning: incompatible pointer types passing 'PyObject *' (aka 'struct _object *') to parameter of type 'PyArrayObject *' (aka 'struct tagPyArrayObject_fields *') [-Wincompatible-pointer-types]
#               PyArray_SETITEM(npyarr->ret, item, value) == -1) {
#                               ^~~~~~~~~~~
#       /private/var/folders/vh/s7vr2c1n3vn041536pmsqsj40000gn/T/pip-build-env-7eo_zy84/overlay/lib/python3.11/site-packages/numpy/_core/include/numpy/ndarrayobject.h:292:32: note: passing argument to parameter 'arr' here
#       PyArray_SETITEM(PyArrayObject *arr, char *itemptr, PyObject *v)
#                                      ^
#       6 warnings and 1 error generated.
#       error: command '/usr/bin/clang' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for pandas
# Failed to build pandas
# ERROR: Could not build wheels for pandas, which is required to install pyproject.toml-based projects
# Note: you may need to restart the kernel to use updated packages.
