# %%
import pandas as pd
import re
import os
import locale
from datetime import datetime
from dateutil import parser

# %%
#data_es = pd.read_csv('/Users/paulinesmirnova/Documents/GitHub/superlexis/data/ES_DATA.csv')
#data_uk = pd.read_csv('/Users/paulinesmirnova/Documents/GitHub/superlexis/data/UK_DATA.csv')
#data_fr = pd.read_csv('/Users/paulinesmirnova/Documents/GitHub/superlexis/data/FR_DATA.csv')
#data_nl = pd.read_csv('/Users/paulinesmirnova/Documents/GitHub/superlexis/data/NL_data_translated.csv.csv')
data = pd.read_csv('/Users/paulinesmirnova/Documents/GitHub/superlexis/supreme_data.csv')
data.head()
# Out:
#    Unnamed: 0                                           headline  \
# 0           1  Het Lombokplein wordt te gevaarlijk'; Bus- en ...
# 1           2  Utrecht is echt een fietshemel'; Route Vuelta ...
# 2           4  Als de auto wegvalt, crasht de economie'; Bran...
# 3           5  Beseffen jullie wel hoe perféct Amsterdam is?'...
# 4           6  Bewijs dat betaalbare woning nog steeds kan'; ...
#
#        news_source             datePublished       region  \
# 0     de telegraaf  April 19, 2023 Wednesday      Utrecht
# 1     de telegraaf   April 20, 2023 Thursday    Nederland
# 2     de telegraaf     April 21, 2023 Friday   Haaglanden
# 3  nrc handelsblad   April 22, 2023 Saturday  1ste Editie
# 4     de telegraaf     April 23, 2023 Sunday    Nederland
#
#         articleSection      length                           byline  \
# 0       REGIO; Blz. 12   423 words                          Michiel
# 1  BINNENLAND; Blz. 12   276 words                      Eric Roeske
# 2       REGIO; Blz. 13   447 words                  Ingrid de Groot
# 3    AMSTERDAM; Blz. 1  1992 words  Stan Putman Foto Simon Lenskens
# 4  FINANCIEEL; Blz. 25   627 words                    Yteke de Jong
#
#                                                 text highlight  \
# 0  Bus- en tramkruising terug naar tekentafel doo...       NaN
# 1  Route Vuelta ligt er strak bij  door  Eric Roe...       NaN
# 2  Brandbrief honderden ondernemers over plannen ...       NaN
# 3  ABSTRACT Not Just Bikes De filmpjes die de Can...       NaN
# 4  Aannemer Van Wijnen schroeft bouwproductie op ...       NaN
#
#                                           translated country  \
# 0  Bus and tram intersection back to drawing boar...      NL
# 1  Route Vuelta is in good shape by Eric Roeske U...      NL
# 2  Urgent letter to hundreds of entrepreneurs abo...      NL
# 3  ABSTRACT Not Just Bikes The videos that Canadi...      NL
# 4  Contractor Van Wijnen increases construction p...      NL
#
#   datePublished_clean
# 0          19/04/2023
# 1          20/04/2023
# 2          21/04/2023
# 3          22/04/2023
# 4          23/04/2023

# %%
# Convert all text in all columns to lowercase
def to_lowercase(text):
    if isinstance(text, str):
        return text.lower()
    return text

# Apply the lowercase conversion to all columns
data = data.applymap(to_lowercase)
# Out:
# /var/folders/98/bbr4z_5s1yj02ygmn84xmtwc0000gn/T/ipykernel_10753/2740884162.py:8: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   data = data.applymap(to_lowercase)

# %% [markdown]
# ## Date function for English language

# %%
def extract_and_format_date(date_str):
    try:
        date_obj = parser.parse(date_str, fuzzy=True)
        return date_obj.strftime("%d/%m/%Y")
    except Exception as e:
        print(f"Error parsing date '{date_str}': {e}")
        return None

# Function to apply to each row in the DataFrame
def extract_and_format_dates_in_df(df, column_name):
    df['date'] = df[column_name].apply(extract_and_format_date)
    return df

# Apply the function to create a new column 'formatted_date'
data = extract_and_format_dates_in_df(data, 'datePublished')

# %%
data.date
# Out:
# 0       19/04/2023
# 1       20/04/2023
# 2       21/04/2023
# 3       22/04/2023
# 4       23/04/2023
#            ...
# 5360    28/12/2016
# 5361    06/03/2009
# 5362    22/01/2014
# 5363    15/08/2018
# 5364    07/07/2016
# Name: date, Length: 5365, dtype: object

# %%
data.date.isna().sum()
# Out:
# 0

# %%
data.date.value_counts()
# Out:
# date
# 21/12/2023    13
# 23/02/2024    11
# 01/06/2024    10
# 13/04/2024    10
# 08/09/2023     9
#               ..
# 03/09/2015     1
# 07/05/2020     1
# 05/03/2020     1
# 19/08/2021     1
# 06/03/2009     1
# Name: count, Length: 2928, dtype: int64

# %%
data
# Out:
#       Unnamed: 0                                           headline  \
# 0              1  het lombokplein wordt te gevaarlijk'; bus- en ...
# 1              2  utrecht is echt een fietshemel'; route vuelta ...
# 2              4  als de auto wegvalt, crasht de economie'; bran...
# 3              5  beseffen jullie wel hoe perféct amsterdam is?'...
# 4              6  bewijs dat betaalbare woning nog steeds kan'; ...
# ...          ...                                                ...
# 5360        5431  mi dica per quale partito ha votato; il sindac...
# 5361        5432  multiutility sì, ma integrata; le aziende loca...
# 5362        5433                                    risiko agricolo
# 5363        5434                                           commenti
# 5364        5435     seniores, finalmente liberidi essere romantici
#
#           news_source                datePublished              region  \
# 0        de telegraaf     april 19, 2023 wednesday             utrecht
# 1        de telegraaf      april 20, 2023 thursday           nederland
# 2        de telegraaf        april 21, 2023 friday          haaglanden
# 3     nrc handelsblad      april 22, 2023 saturday         1ste editie
# 4        de telegraaf        april 23, 2023 sunday           nederland
# ...               ...                          ...                 ...
# 5360       italiaoggi  december 28, 2016 wednesday                 NaN
# 5361       italiaoggi         march 6, 2009 friday                 NaN
# 5362       italiaoggi   january 22, 2014 wednesday                 NaN
# 5363       italiaoggi    august 15, 2018 wednesday                 NaN
# 5364        la stampa        july 7, 2016 thursday  nazionale edizione
#
#                                     articleSection      length  \
# 0                                   regio; blz. 12   423 words
# 1                              binnenland; blz. 12   276 words
# 2                                   regio; blz. 13   447 words
# 3                                amsterdam; blz. 1  1992 words
# 4                              financieel; blz. 25   627 words
# ...                                            ...         ...
# 5360                           primo piano; pag. 6  1081 words
# 5361  rapporto belluno, treviso e vicenza; pag. 25   849 words
# 5362                            attualità; pag. 36   926 words
# 5363                          primo piano; pag. 11   676 words
# 5364                             speciali; pag. 26   823 words
#
#                                   byline  \
# 0                                michiel
# 1                            eric roeske
# 2                        ingrid de groot
# 3        stan putman foto simon lenskens
# 4                          yteke de jong
# ...                                  ...
# 5360  carlo valentini twitter: @cavalent
# 5361                    samuele nottegar
# 5362                                 NaN
# 5363                                 NaN
# 5364                     dario bragaglia
#
#                                                    text  \
# 0     bus- en tramkruising terug naar tekentafel doo...
# 1     route vuelta ligt er strak bij  door  eric roe...
# 2     brandbrief honderden ondernemers over plannen ...
# 3     abstract not just bikes de filmpjes die de can...
# 4     aannemer van wijnen schroeft bouwproductie op ...
# ...                                                 ...
# 5360  bando pubblico: chi vuole essere assunto (per ...
# 5361  acqua, rifiuti, energia: in quale direzione si...
# 5362  granarolo entra in un segmento strategico e in...
# 5363  in italia l'unico ponte che non crolla è quell...
# 5364  non chiamiamoli viaggi per la terza età. gli o...
#
#                                               highlight  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5360  la difesa: il prescelto deve avere la mia fiducia
# 5361  le società che si muovono tra acqua, rifiuti, ...
# 5362                                                NaN
# 5363                                                NaN
# 5364                                                NaN
#
#                                              translated country  \
# 0     bus and tram intersection back to drawing boar...      nl
# 1     route vuelta is in good shape by eric roeske u...      nl
# 2     urgent letter to hundreds of entrepreneurs abo...      nl
# 3     abstract not just bikes the videos that canadi...      nl
# 4     contractor van wijnen increases construction p...      nl
# ...                                                 ...     ...
# 5360  public announcement: who wants to be hired (fo...      it
# 5361  water, waste, energy: in which direction are v...      it
# 5362  granarolo enters a strategic and rapidly growi...      it
# 5363  in italy the only bridge that doesn't collapse...      it
# 5364  let's not call them trips for the elderly. whe...      it
#
#      formatted_date        date
# 0        19/04/2023  19/04/2023
# 1        20/04/2023  20/04/2023
# 2        21/04/2023  21/04/2023
# 3        22/04/2023  22/04/2023
# 4        23/04/2023  23/04/2023
# ...             ...         ...
# 5360     28/12/2016  28/12/2016
# 5361     06/03/2009  06/03/2009
# 5362     22/01/2014  22/01/2014
# 5363     15/08/2018  15/08/2018
# 5364     07/07/2016  07/07/2016
#
# [5365 rows x 14 columns]
